# %% [markdown]
# # Creating balanced data

# %% [markdown]
# - **Purpose**: The purpose of this notebook is to demonstrate the balanced data generation process.
# - **Author**: Shiv Jena
# - **module used**: `dataset.balance_data.py`

# %%
cd ../
# Out:
# /home/shiv/richai

# %%
# importing module
from dataset.balance_data import *
from utils.helpers import get_config

# %% [markdown]
# ## Changes in `configs/config.yaml` to create new save paths
#
# The original source path is the key in the `train` unit, and the save path is the value. In order to securely create balanced dataset without overwriting the original data, it is suggested that the save path be changed as shown below.
# >```
#     dataset:
#           delta: 0.5 #pointnet: 0.5, dgcnn: 0.3
#     train:
#           /data/bvelghe/capstone2022/B/2018B.Sample.EOSlist.CTRL.p.v2.0.4_f.v2.0.4_patched.h5:
#               /fast_scratch_1/capstone_2022/combined_datasets/B.2018B_copy.h5
#           /data/bvelghe/capstone2022/C/2018E.EOSlist.CTRL_patched.h5:
#               /fast_scratch_1/capstone_2022/datasetC_combined_copy.h5
# >```

# %%
# %%time
# Creating and saving balanced data using balance_data()
balance_data(dset_path = get_config("dataset.train").items())
# Out:
# CPU times: user 12 s, sys: 1min 13s, total: 1min 25s
# Wall time: 1min 20s

# %%
# defining original and sample file paths for matching
path_original_b = '/fast_scratch_1/capstone_2022/combined_datasets/B.2018B.h5'
path_sample_b = '/fast_scratch_1/capstone_2022/combined_datasets/B.2018B_copy.h5'
path_original_c = '/fast_scratch_1/capstone_2022/datasetC_combined.h5'
path_sample_c = '/fast_scratch_1/capstone_2022/datasetC_combined.h5'

# %% [markdown]
# ## Testing for Original and Sample B

# %%
# Comparing original and sample files of B dataset
df_b_org = pd.read_hdf(path_original_b)
df_b_sample = pd.read_hdf(path_sample_b)

# %%
df_b_org
# Out:
#         run_id  burst_id  event_id  track_id  track_momentum  chod_time  \
# 0         8584        11    467162         0       20.545891  26.191343
# 1         8585       644     90178         0       18.684219  23.152292
# 2         8594       396    839550         0       19.536823  21.162600
# 3         8596      1116    499071         0       19.072475  -4.647523
# 4         8584       812    242733         2       17.260925  29.883760
# ...        ...       ...       ...       ...             ...        ...
# 205391    8597        11   1134060         0       39.990234   9.208418
# 205392    8597        11   1185901         0       42.756977  20.629349
# 205393    8597        11   1485217         0       43.556774   7.807468
# 205394    8597        11   1492138         0       35.692371  16.451027
# 205395    8597        11   1995404         0       41.408543  21.067675
#
#         ring_radius  ring_centre_pos_x  ring_centre_pos_y  \
# 0        172.459305        -187.848038        -163.433380
# 1        166.742630        -148.628265        -150.348267
# 2        166.987915         -63.194630          82.889381
# 3        165.470795         -50.019455         -39.349384
# 4        162.446198        -120.595657         125.187935
# ...             ...                ...                ...
# 205391   178.909622         -12.610793          -4.642335
# 205392   180.795471        -149.515915         -49.405823
# 205393   183.350784        -137.691193          61.226639
# 205394   180.316269         -38.615685         -61.617775
# 205395   181.751587         -19.638735         -53.850918
#
#         ring_likelihood_pion  ring_likelihood_muon  ring_likelihood_positron  \
# 0               7.914828e-19              1.000000              4.462974e-15
# 1               1.216099e-37              1.000000              4.858268e-37
# 2               1.216099e-37              1.000000              1.216099e-37
# 3               1.216099e-37              1.000000              1.216099e-37
# 4               1.216099e-37              1.000000              1.216099e-37
# ...                      ...                   ...                       ...
# 205391          1.000000e+00              0.018242              1.016588e-08
# 205392          1.000000e+00              0.013767              4.464561e-10
# 205393          1.000000e+00              0.008168              1.698273e-10
# 205394          1.000000e+00              0.130762              4.901688e-08
# 205395          1.000000e+00              0.144452              2.723746e-05
#
#         label  original_index momentum-bin
# 0           0          313820        15-25
# 1           0          346918        15-25
# 2           0          647962        15-25
# 3           0          862768        15-25
# 4           0          228333        15-25
# ...       ...             ...          ...
# 205391      1         1183344        35-45
# 205392      1         1183345        35-45
# 205393      1         1183346        35-45
# 205394      1         1183347        35-45
# 205395      1         1183350        35-45
#
# [205396 rows x 15 columns]

# %%
df_b_sample
# Out:
#         run_id  burst_id  event_id  track_id  track_momentum  chod_time  \
# 0         8600       505   1255898         0       22.134642   7.573945
# 1         8584       471    900821         0       16.544842  14.156938
# 2         8586       520   1157037         0       22.175705   3.747281
# 3         8596       311   1008844         0       23.371750  10.589095
# 4         8585       321   1865296         0       21.112137   9.583098
# ...        ...       ...       ...       ...             ...        ...
# 205391    8597        11   1134060         0       39.990234   9.208418
# 205392    8597        11   1185901         0       42.756977  20.629349
# 205393    8597        11   1485217         0       43.556774   7.807468
# 205394    8597        11   1492138         0       35.692371  16.451027
# 205395    8597        11   1995404         0       41.408543  21.067675
#
#         ring_radius  ring_centre_pos_x  ring_centre_pos_y  \
# 0        171.025391         -21.651001           0.106048
# 1        158.820816         -81.064362          62.893135
# 2        173.562256         -68.062523         -85.532005
# 3        175.663101        -168.908798         151.677185
# 4        171.693588         -27.746183         -19.747335
# ...             ...                ...                ...
# 205391   178.909622         -12.610793          -4.642335
# 205392   180.795471        -149.515915         -49.405823
# 205393   183.350784        -137.691193          61.226639
# 205394   180.316269         -38.615685         -61.617775
# 205395   181.751587         -19.638735         -53.850918
#
#         ring_likelihood_pion  ring_likelihood_muon  ring_likelihood_positron  \
# 0               1.674560e-13              1.000000              1.456128e-28
# 1               1.216099e-37              1.000000              1.216099e-37
# 2               4.248587e-27              1.000000              8.202211e-29
# 3               4.882544e-22              1.000000              4.632577e-19
# 4               9.201775e-30              1.000000              5.465181e-35
# ...                      ...                   ...                       ...
# 205391          1.000000e+00              0.018242              1.016588e-08
# 205392          1.000000e+00              0.013767              4.464561e-10
# 205393          1.000000e+00              0.008168              1.698273e-10
# 205394          1.000000e+00              0.130762              4.901688e-08
# 205395          1.000000e+00              0.144452              2.723746e-05
#
#         label  original_index momentum-bin
# 0           0           95271        15-25
# 1           0          267471        15-25
# 2           0          479092        15-25
# 3           0          947047        15-25
# 4           0          382234        15-25
# ...       ...             ...          ...
# 205391      1         1183344        35-45
# 205392      1         1183345        35-45
# 205393      1         1183346        35-45
# 205394      1         1183347        35-45
# 205395      1         1183350        35-45
#
# [205396 rows x 15 columns]

# %%
# Comparing sample and original for label==1 (pions)
df_b_sample_pions = df_b_sample.query('label==1')
df_b_org_pions = df_b_org.query('label==1')
df_b_sample_pions.equals(df_b_org_pions)
# Out:
# True

# %% [markdown]
# **Conclusion**: This shows two datasets are equal for pion entries. Muon entries could also be equal, if generated with random seed.

# %% [markdown]
# ## Testing for Original and Sample C

# %%
# Comparing original and sample files of B dataset
df_c_org = pd.read_hdf(path_original_c)
df_c_sample = pd.read_hdf(path_sample_c)

# %%
df_c_org
# Out:
#          run_id  burst_id  event_id  track_id  track_momentum  chod_time  \
# 0          9011       887   1800376         0       24.691673  16.837833
# 1          8992      1059    770241         0       23.396029   9.284823
# 2          9007       477   1922012         0       15.891424  22.654669
# 3          8987      1295   1634792         0       16.026428  23.254803
# 4          8971       654   2010374         0       21.888950  24.337191
# ...         ...       ...       ...       ...             ...        ...
# 1731221    8968         7    563388         0       35.011139  16.212551
# 1731222    8968         7    572378         0       38.958267  19.714800
# 1731223    8968         7    583135         0       38.474777  13.620609
# 1731224    8968         7   1461058         0       36.989967  14.916398
# 1731225    8968         7   1879508         0       37.186985  13.901727
#
#          ring_radius  ring_centre_pos_x  ring_centre_pos_y  \
# 0         177.461960         -60.107861         106.794441
# 1         175.237564         -12.228768          11.319837
# 2         152.091827        -241.150375        -172.708389
# 3         155.005783         -65.635712          -0.601753
# 4         172.810287        -231.750687         159.534821
# ...              ...                ...                ...
# 1731221   177.854492        -213.486633          -2.936464
# 1731222   182.430420         -98.754082          92.138535
# 1731223   176.691132        -145.546219         -77.260124
# 1731224   180.464676        -186.481369         -47.899498
# 1731225   179.594803        -184.169525         -46.599884
#
#          ring_likelihood_pion  ring_likelihood_muon  ring_likelihood_positron  \
# 0                5.328789e-10              1.000000              9.393904e-21
# 1                1.080940e-22              1.000000              6.127901e-07
# 2                1.216099e-37              1.000000              1.216099e-37
# 3                1.216099e-37              1.000000              1.216099e-37
# 4                4.307081e-14              1.000000              7.490480e-21
# ...                       ...                   ...                       ...
# 1731221          1.000000e+00              0.000043              2.887881e-20
# 1731222          1.000000e+00              0.146916              3.528800e-07
# 1731223          1.000000e+00              0.001099              5.301323e-11
# 1731224          1.000000e+00              0.004252              8.353033e-16
# 1731225          1.000000e+00              0.145252              4.142398e-08
#
#          label  original_index momentum-bin
# 0            0         2687658        15-25
# 1            0         4676657        15-25
# 2            0         3262259        15-25
# 3            0         5473943        15-25
# 4            0         8071459        15-25
# ...        ...             ...          ...
# 1731221      1         9567636        35-45
# 1731222      1         9567637        35-45
# 1731223      1         9567638        35-45
# 1731224      1         9567646        35-45
# 1731225      1         9567649        35-45
#
# [1731226 rows x 15 columns]

# %%
df_c_sample
# Out:
#          run_id  burst_id  event_id  track_id  track_momentum  chod_time  \
# 0          9011       887   1800376         0       24.691673  16.837833
# 1          8992      1059    770241         0       23.396029   9.284823
# 2          9007       477   1922012         0       15.891424  22.654669
# 3          8987      1295   1634792         0       16.026428  23.254803
# 4          8971       654   2010374         0       21.888950  24.337191
# ...         ...       ...       ...       ...             ...        ...
# 1731221    8968         7    563388         0       35.011139  16.212551
# 1731222    8968         7    572378         0       38.958267  19.714800
# 1731223    8968         7    583135         0       38.474777  13.620609
# 1731224    8968         7   1461058         0       36.989967  14.916398
# 1731225    8968         7   1879508         0       37.186985  13.901727
#
#          ring_radius  ring_centre_pos_x  ring_centre_pos_y  \
# 0         177.461960         -60.107861         106.794441
# 1         175.237564         -12.228768          11.319837
# 2         152.091827        -241.150375        -172.708389
# 3         155.005783         -65.635712          -0.601753
# 4         172.810287        -231.750687         159.534821
# ...              ...                ...                ...
# 1731221   177.854492        -213.486633          -2.936464
# 1731222   182.430420         -98.754082          92.138535
# 1731223   176.691132        -145.546219         -77.260124
# 1731224   180.464676        -186.481369         -47.899498
# 1731225   179.594803        -184.169525         -46.599884
#
#          ring_likelihood_pion  ring_likelihood_muon  ring_likelihood_positron  \
# 0                5.328789e-10              1.000000              9.393904e-21
# 1                1.080940e-22              1.000000              6.127901e-07
# 2                1.216099e-37              1.000000              1.216099e-37
# 3                1.216099e-37              1.000000              1.216099e-37
# 4                4.307081e-14              1.000000              7.490480e-21
# ...                       ...                   ...                       ...
# 1731221          1.000000e+00              0.000043              2.887881e-20
# 1731222          1.000000e+00              0.146916              3.528800e-07
# 1731223          1.000000e+00              0.001099              5.301323e-11
# 1731224          1.000000e+00              0.004252              8.353033e-16
# 1731225          1.000000e+00              0.145252              4.142398e-08
#
#          label  original_index momentum-bin
# 0            0         2687658        15-25
# 1            0         4676657        15-25
# 2            0         3262259        15-25
# 3            0         5473943        15-25
# 4            0         8071459        15-25
# ...        ...             ...          ...
# 1731221      1         9567636        35-45
# 1731222      1         9567637        35-45
# 1731223      1         9567638        35-45
# 1731224      1         9567646        35-45
# 1731225      1         9567649        35-45
#
# [1731226 rows x 15 columns]

# %%
# Comparing both dataframes
df_c_sample.equals(df_c_org)
# Out:
# True

# %% [markdown]
# **Conclusion**: This shows two datasets are identical.
