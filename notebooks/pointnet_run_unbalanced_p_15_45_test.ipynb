# %%
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    roc_curve,
    RocCurveDisplay,
)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Run 1 - Model with momentum and radius
#
# - Momentum and radius
# - delta: 0.2
# - Epochs: 16
# - Train: B and C
# - Test: A (Not Balanced)

# %%
run1_df = pd.read_csv(
   "saved_models/predictions_momentum_radius_16epochs_0.2_0306_unbalanced_p_15_45.csv"
)
cm = confusion_matrix(run1_df["labels"], run1_df["predictions"])
norm_cm = cm.astype("float") * 100.0 / cm.sum(axis=1)[:, np.newaxis]

ConfusionMatrixDisplay(cm).plot()

# %%
ConfusionMatrixDisplay(norm_cm).plot()

# %% [markdown]
# ## Run 2 - Model with momentum (16 epochs)
#
# - Momentum: True
# - Radius: False
# - delta: 0.2
# - Epochs: 16
# - Train: B and C
# - Test: A (Unbalanced)

# %%
run2_df = pd.read_csv("saved_models/pointnet_momentum_only_0506_16epochs_unbalanced_p_15_45.csv")
cm = confusion_matrix(run2_df["labels"], run2_df["predictions"])
norm_cm = cm.astype("float") * 100.0 / cm.sum(axis=1)[:, np.newaxis]

ConfusionMatrixDisplay(cm).plot()

# %%
ConfusionMatrixDisplay(norm_cm).plot()

# %% [markdown]
# ## Run 3 - Model with momentum (24 epochs)
#
# - Momentum: True
# - Radius: False
# - delta: 0.2
# - Epochs: 24
# - Train: B and C
# - Test: A (Unbalanced)

# %%
run3_df = pd.read_csv("saved_models/pointnet_momentum_only_0506_24epochs_unbalanced_p_15_45.csv")
cm = confusion_matrix(run3_df["labels"], run3_df["predictions"])
norm_cm = cm.astype("float") * 100.0 / cm.sum(axis=1)[:, np.newaxis]

ConfusionMatrixDisplay(cm).plot()

# %%
ConfusionMatrixDisplay(norm_cm).plot()

# %% [markdown]
# ## Run 4 - Model with momentum and radius (16 epochs, delta 0.5)
#
# - Momentum: True
# - Radius: True
# - delta: 0.5
# - Epochs: 16
# - Train: B and C
# - Test: A (Unbalanced)

# %%
run4_df = pd.read_csv("saved_models/pointnet_momentum_radius_delta_0.5_16e_0706_unbalanced_p_15_45.csv")
cm = confusion_matrix(run4_df["labels"], run4_df["predictions"])
norm_cm = cm.astype("float") * 100.0 / cm.sum(axis=1)[:, np.newaxis]

ConfusionMatrixDisplay(cm).plot()

# %%
ConfusionMatrixDisplay(norm_cm).plot()

# %%
run4_df.count()
# Out:
# labels           469696
# predictions      469696
# momentum         469696
# probabilities    469696
# dtype: int64

# %% [markdown]
# ## Roc Curve

# %%
models = {
    "momentum: yes, radius: yes, delta: 0.2, epochs: 16": run1_df,
    "momentum: yes, radius: no, delta: 0.2, epochs: 16": run2_df,
    "momentum: yes, radius: no, delta: 0.2, epochs: 24": run3_df,
    "momentum: yes, radius: yes, delta: 0.5, epochs: 16": run4_df,
}


def plot_roc_curves(models):

    fig, ax = plt.subplots(figsize=(10, 10))

    for name, df in models.items():

        fpr, tpr, _ = roc_curve(
            y_true=df["labels"],
            y_score=df["probabilities"],
        )

        disp = RocCurveDisplay(fpr=fpr, tpr=tpr, estimator_name=name)

        disp.plot(ax=ax)

    ax.set_title("Pointnet Test Set A (Unbalanced")
    plt.show()


plot_roc_curves(models)

# %% [markdown]
# ## Pion vs. Muon Effciency on best model
#
# Best model: momentum: yes, radius: yes, delta: 0.5, epochs: 16

# %%
from utils.plotting import wrangle_predictions, plot_efficiencies
from utils.helpers import get_config

mean_momentum = 31.338661
std_momentum = 7.523443
run4_df["momentum"] = run4_df["momentum"] * std_momentum + mean_momentum
wrangled_df = wrangle_predictions(run4_df)
plot_efficiencies(wrangled_df, "Model Efficiencies (Unbalanced Test set , 15 <=p < 45)")
